# %%
from gluoncv import data, utils
from matplotlib import pyplot as plt
import random

# %%
#inst_train_path = "/mnt/muthderd/MIDS/W210/data/annotations_trainval2017/annotations/instances_train2017_updated.json"
#inst_val_path = "/mnt/muthderd/MIDS/W210/data/annotations_trainval2017/annotations/instances_val2017.json"
inst_train_path = "/home/ubuntu/data/annotations/instances_train2017_updated_full"
inst_val_path = "/home/ubuntu/data/annotations/instances_val2017"

# %%
train_data_path = "/home/ubuntu/data/"
val_data_path = "/home/ubuntu/data/"

# %%
train_dataset = data.COCODetection(root=train_data_path, splits=[inst_train_path])
val_dataset = data.COCODetection(root=val_data_path, splits=[inst_val_path])
print('Num of training images:', len(train_dataset))
print('Num of validation images:', len(val_dataset))
# Out:
# loading annotations into memory...
# Done (t=99.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.65s)
# creating index...
# index created!
# Num of training images: 703596
# Num of validation images: 4952

# %%
#train_image, train_label = train_dataset[random.randint(0,703595)]
train_image, train_label = train_dataset[0]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
train_image, train_label = train_dataset[117266]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
train_image, train_label = train_dataset[234532]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
train_image, train_label = train_dataset[351798]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
train_image, train_label = train_dataset[469064]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
train_image, train_label = train_dataset[586330]
bounding_boxes = train_label[:, :4]
class_ids = train_label[:, 4:5]
print('Image size (height, width, RGB):', train_image.shape)
print('Num of objects:', bounding_boxes.shape[0])
print('Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):\n',
      bounding_boxes)
print('Class IDs (num_boxes, ):\n', class_ids)

utils.viz.plot_bbox(train_image.asnumpy(), bounding_boxes, scores=None,
                    labels=class_ids, class_names=train_dataset.classes)
plt.show()
# Out:
# Image size (height, width, RGB): (480, 640, 3)
# Num of objects: 8
# Bounding boxes (num_boxes, x_min, y_min, x_max, y_max):
#  [[  1.08 187.69 611.67 472.53]
#  [311.73   4.31 630.01 231.99]
#  [249.6  229.27 564.84 473.35]
#  [  0.    13.51 433.48 387.63]
#  [376.2   40.36 450.75  85.89]
#  [465.78  38.97 522.85  84.64]
#  [385.7   73.66 468.72 143.17]
#  [364.05   2.49 457.81  72.56]]
# Class IDs (num_boxes, ):
#  [[45.]
#  [45.]
#  [50.]
#  [45.]
#  [49.]
#  [49.]
#  [49.]
#  [49.]]

# %%
random.randint(0,703595)
# Out:
# 604949

# %%
703596/6
# Out:
# 117266.0

# %%
117266*2
# Out:
# 234532

# %%
117266*3
# Out:
# 351798

# %%
117266*4
# Out:
# 469064

# %%
117266*5
# Out:
# 586330
