# %%
import os

# %%
annotations_dir = '/home/ubuntu/data/annotations/'
os.listdir(annotations_dir)
# Out:
# ['captions_train2017.json',
#  'instances_train2017_updated_full.json',
#  'person_keypoints_train2017.json',
#  'instances_train2017_backup.json',
#  'instances_val2017.json',
#  'instances_train2017.json',
#  'person_keypoints_val2017.json',
#  'captions_val2017.json',
#  'instances_train2017_updated.json']

# %%
train_dir = '/home/ubuntu/data/train2017/'
os.listdir(train_dir)
# Out:
# ['000000284686a.jpg',
#  '000000447928a.jpg',
#  '000000343770c.jpg',
#  '000000578197e.jpg',
#  '000000014248b.jpg',
#  '000000388885b.jpg',
#  '000000061943.jpg',
#  '000000046492b.jpg',
#  '000000523959e.jpg',
#  '000000581073d.jpg',
#  '000000463414e.jpg',
#  '000000126096d.jpg',
#  '000000034321d.jpg',
#  '000000370727e.jpg',
#  '000000185328c.jpg',
#  '000000401558d.jpg',
#  '000000312724a.jpg',
#  '000000337962e.jpg',
#  '000000333830a.jpg',
#  '000000506614c.jpg',
#  '000000136289a.jpg',
#  '000000249365b.jpg',
#  '000000250916c.jpg',
#  '000000209746a.jpg',
#  '000000526030d.jpg',
#  '000000580216.jpg',
#  '000000003361d.jpg',
#  '000000277790.jpg',
#  '000000083935c.jpg',
#  '000000389152a.jpg',
#  '000000080433b.jpg',
#  '000000421009.jpg',
#  '000000059278e.jpg',
#  '000000401550d.jpg',
#  '000000386718c.jpg',
#  '000000052563.jpg',
#  '000000260656c.jpg',
#  '000000260720a.jpg',
#  '000000123831e.jpg',
#  '000000556374a.jpg',
#  '000000244215.jpg',
# ...

# %%
len(os.listdir(train_dir))
# Out:
# 704617

# %%
file_list = os.listdir(train_dir)

# %%
file_list[0]
# Out:
# '000000284686a.jpg'

# %%
int(file_list[0][:-5]) + 100000000000
# Out:
# 100000284686

# %%
counter = 0
for filename in file_list:
    if 'a' in filename:
        counter+=1
        
print(counter)
# Out:
# 117266

# %%
counter = 0
for filename in file_list:
    if 'b' in filename:
        counter+=1
        
print(counter)
# Out:
# 117266

# %%
counter = 0
for filename in file_list:
    if 'c' in filename:
        counter+=1
        
print(counter)
# Out:
# 117266

# %%
counter = 0
for filename in file_list:
    if 'd' in filename:
        counter+=1
        
print(counter)
# Out:
# 117266

# %%
counter = 0
for filename in file_list:
    if 'e' in filename:
        counter+=1
        
print(counter)
# Out:
# 117266

# %%
train_dir + file_list[0]
# Out:
# '/home/ubuntu/data/train2017/000000284686a.jpg'

# %%
pwd
# Out:
# '/home/ubuntu/computer-vision-for-ewaste'

# %%
os.chdir(train_dir)
print(train_dir)
# Out:
# /home/ubuntu/data/train2017/

# %%
for filename in file_list:
    if 'a' in filename:
        rename_1 = str(int(filename[:-5]) + 100000000000) + '.jpg'
        os.rename(filename, rename_1)
    if 'b' in filename:
        rename_2 = str(int(filename[:-5]) + 200000000000) + '.jpg'
        os.rename(filename, rename_2)
    if 'c' in filename:
        rename_3 = str(int(filename[:-5]) + 300000000000) + '.jpg'
        os.rename(filename, rename_3)
    if 'd' in filename:
        rename_4 = str(int(filename[:-5]) + 400000000000) + '.jpg'
        os.rename(filename, rename_4)
    if 'e' in filename:
        rename_5 = str(int(filename[:-5]) + 500000000000) + '.jpg'
        os.rename(filename, rename_5)
